# %%
# Import Libaries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# # Data Searching

# %%
# Read In Data
df = pd.read_csv(r"C:\Users\DELL\Desktop\SQL\Portfolio Project\Movie Industry-Correlation in Python\movies.csv")
#df

# %%
# Look At Data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Let's see if their is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Drop the NaN values
df= df.dropna()

# %%
# Let's check if their is any missing data again
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Specify Column to work
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
# Converting the columns have type float64 to interger64
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
#As Data has NAN value so the code above not work before we remove NAN value by dropna()
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\3206745946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['budget'] = df['budget'].astype('int64')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\3206745946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].astype('int64')
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# ...

# %% [markdown]
# # DATA CLEANING

# %%
# Column 'year', 'released' should match together
# So We need to Create correct Year column
# df['released'].astype(str).str[:4] This code only work for filtering the month not year
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# Check 
df[['year', 'yearcorrect','released']]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8524\77964130.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
#       year  yearcorrect                           released
# 0     1980         1980      June 13, 1980 (United States)
# 1     1980         1980       July 2, 1980 (United States)
# 2     1980         1980      June 20, 1980 (United States)
# 3     1980         1980       July 2, 1980 (United States)
# 4     1980         1980      July 25, 1980 (United States)
# ...    ...          ...                                ...
# 7648  2020         2020   January 17, 2020 (United States)
# 7649  2020         2020  February 14, 2020 (United States)
# ...

# %%
# Order By 'gross' column
df.sort_values(by =['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# New Setting to Check all row value from this dataframe
pd.set_option('display.max_rows', None)

# %%
# Check and Drop Duplicate
#df['company'].drop_duplicates().sort_values(ascending = False)

# %% [markdown]
# # Finding Correlations in Data

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Budget high correlation
# Company high correlation

# %%
# Scatter Plot with budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget vs Gross Earning')

plt.xlabel('Gross Earning')

plt.ylabel('Budget For Film')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Regression Plot the budget vs gross using seaborn

sns.regplot(x="budget", y="gross", data=df, scatter_kws = {"color": "red"}, line_kws = {"color": "blue"})

plt.show()

# %%
# Let's start looking at correlation
df_corr = df[['budget', 'gross', 'runtime','score', 'votes','year']]

correlation_matrix = df_corr.corr(method = 'pearson')
correlation_matrix
# Witht the result between budget and gross 1 ~ 0.74 => Hight correlation between budget and gross
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740395  0.320447  0.076254  0.442429  0.329321
# gross    0.740395  1.000000  0.245216  0.186258  0.630757  0.257486
# runtime  0.320447  0.245216  1.000000  0.399451  0.309212  0.120811
# score    0.076254  0.186258  0.399451  1.000000  0.409182  0.097995
# votes    0.442429  0.630757  0.309212  0.409182  1.000000  0.222945
# year     0.329321  0.257486  0.120811  0.097995  0.222945  1.000000

# %%
# View in HeatMap
sns.heatmap(correlation_matrix,annot = True)
plt.title('Correlation Matrix with Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Correlation Matrix')

plt.show()

# %%
# Coverting Every have object type to numeric type
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
          df_numerized[col_name]=df_numerized[col_name].astype('category')
          df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
correlation_matrix = df_numerized.corr()
correlation_matrix.head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
#
#              gross   company   runtime
# name      0.005533  0.009211  0.010392
# rating   -0.107339 -0.032943  0.062145
# ...

# %%
correlation_matrix
sns.heatmap(correlation_matrix,annot = True)
plt.title('Correlation Matrix with Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Correlation Matrix')

plt.show()

# %%
# Get Pair comparision with unstack() method
corr_pairs = correlation_matrix.unstack()
corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# budget  genre    -0.356564
# genre   budget   -0.356564
#         gross    -0.235650
# gross   genre    -0.235650
# rating  budget   -0.176002
# dtype: float64

# %%
# Check how corr
# High Correlation with > 0.5
high_corr = sorted_pairs[(sorted_pairs)> 0.5]
high_corr
# Out:
# gross     votes       0.630757
# votes     gross       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
